# %%
import pandas as pd
import dataprep
from pathlib import Path
from dataprep.datasets import load_dataset
from dataprep.eda import create_report
from dataprep.eda import plot, plot_correlation, plot_missing

# %%
pd.options.display.max_columns = None

salling_agg = pd.read_csv(Path(r'./salling_data/AGGREGATIONS/data.csv'))
salling_combinations = pd.read_csv(Path(r'./salling_data/ATTRIBUTE_COMBINATIONS/data.csv'))
salling_time_windows = pd.read_csv(Path(r'./salling_data/TIME_WINDOWS/data.csv'))
salling_results = pd.read_csv(Path(r'./salling_data/Results/SALLING_RESULTS.csv'))
display(salling_agg.head(10))
display(salling_agg.describe())
display("unique values of measure name", salling_agg["MEASURE_NAME"].unique())
# Out:
#       ATTRIBUTE_COMBINATION_HASH_ID                 WINDOW_START MEASURE_NAME  \
# 0  B59C4E4BFCEC5601795A74ECA11904BC  2021-02-08 00:00:00.0000000  SALES_UNITS
# 1  BE90687E2E50DDCCFC4FC8F43A899939  2021-02-27 00:00:00.0000000  SALES_UNITS
# 2  B9E7A9A05E12DF084EC38E215C456F0A  2021-02-27 00:00:00.0000000  SALES_UNITS
# 3  C6B198A2CEB35F13AC5F8D5BA7A2A717  2021-02-08 00:00:00.0000000  SALES_UNITS
# 4  3699D10EC5ACEA0DC05A1529FAB5B297  2021-02-27 00:00:00.0000000  SALES_UNITS
# 5  53F2DEF355B1ABD820F963D4D04257DD  2021-02-08 00:00:00.0000000  SALES_UNITS
# 6  E0BEB2C5B69A60DB5621AB2E24F6D6E5  2021-02-27 00:00:00.0000000  SALES_UNITS
# 7  06890B794C4FFC127CE7030D7BF6AB9B  2021-02-08 00:00:00.0000000  SALES_UNITS
# 8  C03D3BA7A6F92B0D85BEDF4D102E1FAF  2021-02-27 00:00:00.0000000  SALES_UNITS
# 9  EB74A065C78288335051746FA7972659  2021-02-08 00:00:00.0000000  SALES_UNITS
#
#    MEASURE_VALUE
# 0            1.0
# 1            2.0
# 2            2.0
# 3            1.0
# 4            3.0
# ...

# %%
# view column information
display("Attribute combinations column types",salling_combinations.dtypes)
display("Attribute combinations columns",salling_combinations.columns)
display("Attribute combinations data:",salling_combinations.head(10))

# display all unique values of columns
for col in salling_combinations.columns[2:]:
    display("Unique values of column: " + str(salling_combinations[col]) , salling_combinations[col].unique())
   # display( salling_combinations["ATTRIBUTE_PROD_LEVEL_2"].unique())
   # display( salling_combinations["ATTRIBUTE_PROD_LEVEL_3"].unique())
# Out:
# 'Attribute combinations column types'
# ATTRIBUTE_COMBINATION_HASH_ID     object
# LAST_OBSERVED                     object
# INVERSE_ATTRIBUTE_COUNT          float64
# ATTRIBUTE_POSTAL_CODE            float64
# ATTRIBUTE_PROD_LEVEL_1            object
# ATTRIBUTE_PROD_LEVEL_2            object
# ATTRIBUTE_PROD_LEVEL_3            object
# dtype: object
# 'Attribute combinations columns'
# Index(['ATTRIBUTE_COMBINATION_HASH_ID', 'LAST_OBSERVED',
#        'INVERSE_ATTRIBUTE_COUNT', 'ATTRIBUTE_POSTAL_CODE',
#        'ATTRIBUTE_PROD_LEVEL_1', 'ATTRIBUTE_PROD_LEVEL_2',
#        'ATTRIBUTE_PROD_LEVEL_3'],
#       dtype='object')
# 'Attribute combinations data:'
#       ATTRIBUTE_COMBINATION_HASH_ID                LAST_OBSERVED  \
# 0  F6B55821354B0A6A067D160B7EE4C473  2022-04-11 00:00:00.0000000
# 1  4EED91AB2DBF711231FCE6072E5C76ED  2022-04-11 00:00:00.0000000
# 2  19618FA5E3CF06BDB2F3B76A1E5397B4  2022-04-11 00:00:00.0000000
# ...

# %%
display("Time windows column types",salling_time_windows.dtypes)
display("Time windows columns",salling_time_windows.columns)
salling_time_windows.head(10)
# Out:
# 'Time windows cols type'
# WINDOW_START            object
# WINDOW_END              object
# COUNT_DATA_POINTS      float64
# LOAD_STATUS             object
# LOAD_TIMESTAMP          object
# LOAD_RETRIES             int64
# ETL_STATUS              object
# ETL_TIMESTAMP           object
# ETL_RETRIES              int64
# AD_STATUS               object
# AD_TIMESTAMP            object
# AD_RETRIES               int64
# RESULT_STATUS           object
# RESULT_TIMESTAMP        object
# RESULT_RETRIES           int64
# REPORTING_STATUS        object
# REPORTING_TIMESTAMP     object
# REPORTING_RETRIES        int64
# PROCESSING_COMPLETE      int64
# dtype: object
# 'Time windows columns'
# Index(['WINDOW_START', 'WINDOW_END', 'COUNT_DATA_POINTS', 'LOAD_STATUS',
#        'LOAD_TIMESTAMP', 'LOAD_RETRIES', 'ETL_STATUS', 'ETL_TIMESTAMP',
#        'ETL_RETRIES', 'AD_STATUS', 'AD_TIMESTAMP', 'AD_RETRIES',
#        'RESULT_STATUS', 'RESULT_TIMESTAMP', 'RESULT_RETRIES',
# ...

# %%
display("Result column types",salling_results.dtypes)
display("Result columns",salling_results.columns)
salling_results.head(10)

pd.merge(sa)
# Out:
# 'Result column types'
# Unnamed: 0                         int64
# RESULT_HASH_ID                     int64
# WINDOW_START                      object
# ATTRIBUTE_COMBINATION_HASH_ID     object
# MEASURE_NAME                      object
# MEASURE_VALUE                    float64
# IS_ANOMALY                         int64
# ANOMALY_TYPE                      object
# ANOMALY_SUBTYPE                   object
# RELEVANCE                        float64
# RELEVANCE_LABEL                   object
# SUPPORT                          float64
# RISK_RATIO                       float64
# dtype: object
# 'Result columns'
# Index(['Unnamed: 0', 'RESULT_HASH_ID', 'WINDOW_START',
#        'ATTRIBUTE_COMBINATION_HASH_ID', 'MEASURE_NAME', 'MEASURE_VALUE',
#        'IS_ANOMALY', 'ANOMALY_TYPE', 'ANOMALY_SUBTYPE', 'RELEVANCE',
#        'RELEVANCE_LABEL', 'SUPPORT', 'RISK_RATIO'],
#       dtype='object')
#    Unnamed: 0       RESULT_HASH_ID WINDOW_START  \
# ...
