# %%
# %config Completer.use_jedi = False

# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
csv = pd.read_csv("C:/Users/D062732/Downloads/JPM.csv")

# %%
print(csv.head(5))
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2000-01-03  49.833332  50.250000  48.083332  48.583332  24.597769  12019200
# 1  2000-01-04  47.083332  47.458332  46.125000  47.250000  24.058060  11723400
# 2  2000-01-05  46.833332  48.375000  46.000000  46.958332  23.909559   8714550
# 3  2000-01-06  46.750000  48.625000  46.500000  47.625000  24.249004   8369250
# 4  2000-01-07  48.416668  49.000000  47.333332  48.500000  24.694513   6571950

# %%
csv["Close"].plot()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(csv["Adj Close"], color = "red", label = "Open Price")
plt.plot(csv["Close"], color = "blue", label = "Close Price")
plt.xlabel("stocks")
plt.ylabel("price")
plt.show()

# %%
# Train the model with close price

df_close_price = csv.iloc[:,4:5].values
print(df_close_price)
print(df_close_price.shape)
# Out:
# [[ 48.583332]
#  [ 47.25    ]
#  [ 46.958332]
#  ...
#  [125.339996]
#  [125.010002]
#  [125.360001]]
# (5283, 1)
